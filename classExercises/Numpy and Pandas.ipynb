# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Plotting packages: Matplotlib, Seaborn, GGPlot, Plotly
# Pandas is for data manipulation. Spark does what pandas does, but better, and more.
# Hadoop provides compute and storage.
# Spark provides the computation, but not the storage.

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %% [markdown]
# # Data Structures in Pandas
# * DataFrame
# * Series

# %%
x = [1,2,3,4,5]
s = pd.Series(x,name="x")

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: x, dtype: int64

# %%
s.mean()
# Out:
# 3.0

# %%
s.std()
# Out:
# 1.5811388300841898

# %%
s.sum()
# Out:
# 15

# %%
y = [e**2 for e in x]

# %%
code = ["a","b","c","d","e"]

# %%
zipped_data = zip(x,y,code)

# %%
zipped_data

# %%
data = pd.DataFrame(list(zipped_data), columns=["x","y","code"])

# %%
data
# Out:
#    x   y code
# 0  1   1    a
# 1  2   4    b
# 2  3   9    c
# 3  4  16    d
# 4  5  25    e

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (5, 3)

# %%
data.dtypes
# Out:
# x        int64
# y        int64
# code    object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       5 non-null      int64
#  1   y       5 non-null      int64
#  2   code    5 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
data.describe()
# Out:
#               x         y
# count  5.000000   5.00000
# mean   3.000000  11.00000
# std    1.581139   9.66954
# min    1.000000   1.00000
# 25%    2.000000   4.00000
# 50%    3.000000   9.00000
# 75%    4.000000  16.00000
# max    5.000000  25.00000

# %%
dir(data)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
data[["x","y"]]
# Out:
#    x   y
# 0  1   1
# 1  2   4
# 2  3   9
# 3  4  16
# 4  5  25

# %%
data[["x","y"]].mean()
# Out:
# x     3.0
# y    11.0
# dtype: float64

# %%
data[["x","y"]].agg(["count","mean","median","var","std","kurt","skew"])
# Out:
#                x          y
# count   5.000000   5.000000
# mean    3.000000  11.000000
# median  3.000000   9.000000
# var     2.500000  93.500000
# std     1.581139   9.669540
# kurt   -1.200000  -0.642340
# skew    0.000000   0.699589

# %%
type(data.iloc[:,1]) #This returns a series
# Out:
# pandas.core.series.Series

# %%
type(data.iloc[:,0:1]) #This returns a Dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[:,1] # This is a series
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: YY, dtype: int64

# %%
data.iloc[:,0:1] # This is a dataframe
# Out:
#    XX
# 0   1
# 1   2
# 2   3
# 3   4
# 4   5

# %%
map = {"x": "XX", "y": "YY", "code": "CODE"}
data = data.rename(columns=map)

# %%
data
# Out:
#    XX  YY CODE
# 0   1   1    a
# 1   2   4    b
# 2   3   9    c
# 3   4  16    d
# 4   5  25    e

# %%
data.index = ["john", "mary", "jack", "jackie", "jill"]

# %%
data
# Out:
#         XX  YY CODE
# john     1   1    a
# mary     2   4    b
# jack     3   9    c
# jackie   4  16    d
# jill     5  25    e

# %%
#Reset the index to default
data.reset_index()
# Out:
#     index  XX  YY CODE
# 0    john   1   1    a
# 1    mary   2   4    b
# 2    jack   3   9    c
# 3  jackie   4  16    d
# 4    jill   5  25    e

# %%
data # But you need to assign it to itself, or those changes are just temporary
# Out:
#         XX  YY CODE
# john     1   1    a
# mary     2   4    b
# jack     3   9    c
# jackie   4  16    d
# jill     5  25    e

# %%
data["nothing"] = 0

# %%
data
# Out:
#         XX  YY CODE  nothing
# john     1   1    a        0
# mary     2   4    b        0
# jack     3   9    c        0
# jackie   4  16    d        0
# jill     5  25    e        0

# %%
del(data["nothing"])

# %%
data
# Out:
#         XX  YY CODE
# john     1   1    a
# mary     2   4    b
# jack     3   9    c
# jackie   4  16    d
# jill     5  25    e

# %%
# Or you can use Drop
data["nothing"] = 0
data
# Out:
#         XX  YY CODE  nothing
# john     1   1    a        0
# mary     2   4    b        0
# jack     3   9    c        0
# jackie   4  16    d        0
# jill     5  25    e        0

# %%
data=data.drop(columns=["nothing"])

# %%
data
# Out:
#         XX  YY CODE
# john     1   1    a
# mary     2   4    b
# jack     3   9    c
# jackie   4  16    d
# jill     5  25    e

# %%
#or rows
data = data.reset_index()
data.drop(index=[0,3],axis=0)
# Out:
#    level_0 index  XX  YY CODE
# 1        1  mary   2   4    b
# 2        2  jack   3   9    c
# 4        4  jill   5  25    e
